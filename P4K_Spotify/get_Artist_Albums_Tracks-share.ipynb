# %%
# install spotipy to anaconda for first time - don't run again
# https://medium.com/@maxtingle/getting-started-with-spotifys-api-spotipy-197c3dc6353b
pip install spotipy

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials #To access authorised Spotify data

client_id_input = 'XXX'
client_secret_input = 'XXX'


client_id = client_id_input
client_secret = client_secret_input
client_credentials_manager = SpotifyClientCredentials(client_id=client_id, client_secret=client_secret)
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager) #spotify object to access API

name = "Grouper" #chosen artist
result = sp.search(name) #search query
print(result['tracks']['items'][0]['artists'])
# Out:
# [{'external_urls': {'spotify': 'https://open.spotify.com/artist/31uyAcnY0kjjKKIQZMKX4i'}, 'href': 'https://api.spotify.com/v1/artists/31uyAcnY0kjjKKIQZMKX4i', 'id': '31uyAcnY0kjjKKIQZMKX4i', 'name': 'Grouper', 'type': 'artist', 'uri': 'spotify:artist:31uyAcnY0kjjKKIQZMKX4i'}]

# %%
# Extract Artist's albums

#Extract Artist's uri
artist_uri = result['tracks']['items'][0]['artists'][0]['uri']
#Pull all of the artist's albums
sp_albums = sp.artist_albums(artist_uri, album_type='album')
#Store artist's albums' names' and uris in separate lists
album_names = []
album_uris = []
for i in range(len(sp_albums['items'])):
    album_names.append(sp_albums['items'][i]['name'])
    album_uris.append(sp_albums['items'][i]['uri'])
    
print(album_names)
album_uris
#Keep names and uris in same order to keep track of duplicate albums
# Out:
# ['Grid of Points', 'Ruins', 'The Man Who Died in His Boat', 'A I A: Alien Observer', 'A I A: Dream Loss', 'Dragging a Dead Deer Up a Hill', 'Cover the Windows and the Walls', 'Wide', 'Way Their Crept', 'Way Their Crept']
# ['spotify:album:5wy223m8JP5DBOvgumFgN8',
#  'spotify:album:5ElYoVUqRQIlDekD1v6aKa',
#  'spotify:album:2arK6QEmfa25k2feNozs9e',
#  'spotify:album:4Z1BFX1oBckY8bhGEWMYmi',
#  'spotify:album:5l4dgQzaAkmbTpueLhSR3q',
#  'spotify:album:0r1ffFQRFvtthTdLV2ZPWL',
#  'spotify:album:6FDT9qQNRT6ntiEhTI8SI6',
#  'spotify:album:3iLSxt5fh8f0vN89861WnE',
#  'spotify:album:6faiJmDRFljT7N1R9lllDv',
#  'spotify:album:2UbTwil7eR6Lov37LRyVhb']

# %%
# Grab songs from each album

def albumSongs(uri, spotify_albums):
    album = uri #assign album uri to a_name
    spotify_albums[album] = {} #Creates dictionary for that specific album
    
    #Create keys-values of empty lists inside nested dictionary for album
    spotify_albums[album]['album'] = [] #create empty list
    spotify_albums[album]['track_number'] = []
    spotify_albums[album]['id'] = []
    spotify_albums[album]['name'] = []
    spotify_albums[album]['uri'] = []
    
    tracks = sp.album_tracks(album) #pull data on album tracks
    for n in range(len(tracks['items'])): #for each song track
            spotify_albums[album]['album'].append(album_names[album_count]) #append album name tracked via album_count
            spotify_albums[album]['track_number'].append(tracks['items'][n]['track_number'])
            spotify_albums[album]['id'].append(tracks['items'][n]['id'])
            spotify_albums[album]['name'].append(tracks['items'][n]['name'])
            spotify_albums[album]['uri'].append(tracks['items'][n]['uri'])

# %%
# global albums tracker for this artist
spotify_albums = {}
album_count = 0
for i in album_uris: #each album
    albumSongs(i, spotify_albums)
    print("Album " + str(album_names[album_count]) + " songs has been added to spotify_albums dictionary")
    album_count+=1 #Updates album count once all tracks have been added
# Out:
# Album Grid of Points songs has been added to spotify_albums dictionary
# Album Ruins songs has been added to spotify_albums dictionary
# Album The Man Who Died in His Boat songs has been added to spotify_albums dictionary
# Album A I A: Alien Observer songs has been added to spotify_albums dictionary
# Album A I A: Dream Loss songs has been added to spotify_albums dictionary
# Album Dragging a Dead Deer Up a Hill songs has been added to spotify_albums dictionary
# Album Cover the Windows and the Walls songs has been added to spotify_albums dictionary
# Album Wide songs has been added to spotify_albums dictionary
# Album Way Their Crept songs has been added to spotify_albums dictionary
# Album Way Their Crept songs has been added to spotify_albums dictionary

# %%
# Only run to visualize
spotify_albums
# Out:
# {'spotify:album:5wy223m8JP5DBOvgumFgN8': {'album': ['Grid of Points',
#    'Grid of Points',
#    'Grid of Points',
#    'Grid of Points',
#    'Grid of Points',
#    'Grid of Points',
#    'Grid of Points'],
#   'track_number': [1, 2, 3, 4, 5, 6, 7],
#   'id': ['7wAqt1ZqGRzY2CiVBpBAG8',
#    '4AOl8fZE2eTR6vocAYxqP4',
#    '3Wgm9FhrruO71VDFA6kxgj',
#    '6rvzXO4pZk1CgZPbc6maBd',
#    '76m9qTSWvcVVhyC3JW7tnY',
#    '1qfJaIIBYBfl5QNXHjfT6Y',
#    '4swkvu47VJuVrFdShw76jr'],
#   'name': ['The Races',
#    'Parking Lot',
#    'Driving',
#    'Thanksgiving Song',
#    'Birthday Song',
#    'Blouse',
#    'Breathing'],
#   'uri': ['spotify:track:7wAqt1ZqGRzY2CiVBpBAG8',
#    'spotify:track:4AOl8fZE2eTR6vocAYxqP4',
#    'spotify:track:3Wgm9FhrruO71VDFA6kxgj',
#    'spotify:track:6rvzXO4pZk1CgZPbc6maBd',
#    'spotify:track:76m9qTSWvcVVhyC3JW7tnY',
#    'spotify:track:1qfJaIIBYBfl5QNXHjfT6Y',
#    'spotify:track:4swkvu47VJuVrFdShw76jr']},
# ...

# %%
# Grab audio features for each song

def audio_features(album, spotify_albums):
    #Add new key-values to store audio features
    spotify_albums[album]['acousticness'] = []
    spotify_albums[album]['danceability'] = []
    spotify_albums[album]['energy'] = []
    spotify_albums[album]['instrumentalness'] = []
    spotify_albums[album]['liveness'] = []
    spotify_albums[album]['loudness'] = []
    spotify_albums[album]['speechiness'] = []
    spotify_albums[album]['tempo'] = []
    spotify_albums[album]['valence'] = []
    spotify_albums[album]['popularity'] = []
    #create a track counter
    track_count = 0
    for track in spotify_albums[album]['uri']:
        #pull audio features per track
        features = sp.audio_features(track)
        
        #Append to relevant key-value
        spotify_albums[album]['acousticness'].append(features[0]['acousticness'])
        spotify_albums[album]['danceability'].append(features[0]['danceability'])
        spotify_albums[album]['energy'].append(features[0]['energy'])
        spotify_albums[album]['instrumentalness'].append(features[0]['instrumentalness'])
        spotify_albums[album]['liveness'].append(features[0]['liveness'])
        spotify_albums[album]['loudness'].append(features[0]['loudness'])
        spotify_albums[album]['speechiness'].append(features[0]['speechiness'])
        spotify_albums[album]['tempo'].append(features[0]['tempo'])
        spotify_albums[album]['valence'].append(features[0]['valence'])
        #popularity is stored elsewhere
        pop = sp.track(track)
        spotify_albums[album]['popularity'].append(pop['popularity'])
        track_count+=1

# %%
# Loop through albums extracting the audio features

import time
import numpy as np
sleep_min = 2
sleep_max = 5
start_time = time.time()
request_count = 0
for i in spotify_albums:
    audio_features(i, spotify_albums)
    request_count+=1
    if request_count % 5 == 0:
        print(str(request_count) + " playlists completed")
        time.sleep(np.random.uniform(sleep_min, sleep_max))
        print('Loop #: {}'.format(request_count))
        print('Elapsed Time: {} seconds'.format(time.time() - start_time))
# Out:
# 5 playlists completed
# Loop #: 5
# Elapsed Time: 9.487541198730469 seconds
# 10 playlists completed
# Loop #: 10
# Elapsed Time: 18.31551170349121 seconds

# %%
# Organise our data into a dictionary to turn into a dataframe

dic_df = {}
dic_df['album'] = []
dic_df['track_number'] = []
dic_df['id'] = []
dic_df['name'] = []
dic_df['uri'] = []
dic_df['acousticness'] = []
dic_df['danceability'] = []
dic_df['energy'] = []
dic_df['instrumentalness'] = []
dic_df['liveness'] = []
dic_df['loudness'] = []
dic_df['speechiness'] = []
dic_df['tempo'] = []
dic_df['valence'] = []
dic_df['popularity'] = []
for album in spotify_albums: 
    for feature in spotify_albums[album]:
        dic_df[feature].extend(spotify_albums[album][feature])
        
len(dic_df['album'])
# Out:
# 85

# %%
# Convert into dataframe
import pandas as pd
df = pd.DataFrame.from_dict(dic_df)
df
# Out:
#               album  track_number                      id  \
# 0    Grid of Points             1  7wAqt1ZqGRzY2CiVBpBAG8
# 1    Grid of Points             2  4AOl8fZE2eTR6vocAYxqP4
# 2    Grid of Points             3  3Wgm9FhrruO71VDFA6kxgj
# 3    Grid of Points             4  6rvzXO4pZk1CgZPbc6maBd
# 4    Grid of Points             5  76m9qTSWvcVVhyC3JW7tnY
# ..              ...           ...                     ...
# 80  Way Their Crept             5  6oa3Hi3B1M3eOtEr3wPAA8
# 81  Way Their Crept             6  2wSGygVc25oSsYwC26fLJk
# 82  Way Their Crept             7  0bu1WHLaNZaaxSqpp9xvmI
# 83  Way Their Crept             8  4LAmOLDuUtlm1mlBcw5Ltb
# 84  Way Their Crept             9  0rfLCtyxdJqPvTwcmQa1kx
#
#                       name                                   uri  \
# 0                The Races  spotify:track:7wAqt1ZqGRzY2CiVBpBAG8
# 1              Parking Lot  spotify:track:4AOl8fZE2eTR6vocAYxqP4
# 2                  Driving  spotify:track:3Wgm9FhrruO71VDFA6kxgj
# ...

# %%
# Remove duplicates
print(len(df))
final_df = df.sort_values('popularity', ascending=False).drop_duplicates('name').sort_index()
print(len(final_df))
# Out:
# 85
# 79

# %%
final_df
# Out:
#               album  track_number                      id  \
# 0    Grid of Points             1  7wAqt1ZqGRzY2CiVBpBAG8
# 1    Grid of Points             2  4AOl8fZE2eTR6vocAYxqP4
# 2    Grid of Points             3  3Wgm9FhrruO71VDFA6kxgj
# 3    Grid of Points             4  6rvzXO4pZk1CgZPbc6maBd
# 4    Grid of Points             5  76m9qTSWvcVVhyC3JW7tnY
# ..              ...           ...                     ...
# 80  Way Their Crept             5  6oa3Hi3B1M3eOtEr3wPAA8
# 81  Way Their Crept             6  2wSGygVc25oSsYwC26fLJk
# 82  Way Their Crept             7  0bu1WHLaNZaaxSqpp9xvmI
# 83  Way Their Crept             8  4LAmOLDuUtlm1mlBcw5Ltb
# 84  Way Their Crept             9  0rfLCtyxdJqPvTwcmQa1kx
#
#                       name                                   uri  \
# 0                The Races  spotify:track:7wAqt1ZqGRzY2CiVBpBAG8
# 1              Parking Lot  spotify:track:4AOl8fZE2eTR6vocAYxqP4
# 2                  Driving  spotify:track:3Wgm9FhrruO71VDFA6kxgj
# ...

# %%
# Save to CSV
final_df.to_csv("grouper_all_tracks.csv")

# %%
# searching for an album
album_name = 'cybersex'
artist_name = "blackbear"
# query=f"album:{album_name}%20artist:{artist_name}&type=album"
query=f"album:{album_name}&type=album"


# search(q, limit=10, offset=0, type='track', market=None)
temp_album = sp.search(q=album_name, type='album')

# %%
# searching for an album
album_name = 'Mono No Aware'
artist_name = "Various Artists"
query=f"album:{album_name} artist:{artist_name}"


# search(q, limit=10, offset=0, type='track', market=None)
temp_album = sp.search(q=album_name, type='album', limit=1)

# %%
import json
# print(temp_album)
print(json.dumps(temp_album, indent=4, ensure_ascii=False))  # reading back from JSON
# Out:
# {
#     "albums": {
#         "href": "https://api.spotify.com/v1/search?query=Mono+No+Aware&type=album&offset=0&limit=1",
#         "items": [
#             {
#                 "album_type": "album",
#                 "artists": [
#                     {
#                         "external_urls": {
#                             "spotify": "https://open.spotify.com/artist/0LyfQWJT6nXafLPZqxe9Of"
#                         },
#                         "href": "https://api.spotify.com/v1/artists/0LyfQWJT6nXafLPZqxe9Of",
#                         "id": "0LyfQWJT6nXafLPZqxe9Of",
#                         "name": "Various Artists",
#                         "type": "artist",
#                         "uri": "spotify:artist:0LyfQWJT6nXafLPZqxe9Of"
#                     }
#                 ],
#                 "available_markets": [
#                     "AD",
#                     "AE",
#                     "AG",
#                     "AL",
#                     "AM",
# ...

# %%
# get the album's uri:
if temp_album['albums']['total'] != 0:
    temp_album_uri = temp_album['albums']['items'][0]['uri']
    print(temp_album_uri)
#     temp_album_returned = sp.album(temp_album_uri)
#     print(json.dumps(temp_album_returned, indent=4, ensure_ascii=False))  # reading back from JSON
    
    temp_album_dict = {}
    albumSongs(temp_album_uri, temp_album_dict)
    audio_features(temp_album_uri, temp_album_dict)

else:
    print('No album found.')
# Out:
# spotify:album:3fHY1FPrS7L6ecZtBcEaj0
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-76-9b796cb06811> in <module>
#       7
#       8     temp_album_dict = {}
# ----> 9     albumSongs(temp_album_uri, temp_album_dict)
#      10     audio_features(temp_album_uri, temp_album_dict)
#      11
#
# <ipython-input-75-5f37c287e63e> in albumSongs(uri, spotify_albums)
#      14     tracks = sp.album_tracks(album) #pull data on album tracks
#      15     for n in range(len(tracks['items'])): #for each song track
# ---> 16             spotify_albums[album]['album'].append(album_names[album_count]) #append album name tracked via album_count
#      17             spotify_albums[album]['track_number'].append(tracks['items'][n]['track_number'])
#      18             spotify_albums[album]['id'].append(tracks['items'][n]['id'])
#
# IndexError: list index out of range
